# %%
import numpy as np
import cv2, time

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
# %%writefile id_number.py
# %load id_number.py
import numpy as np
from skimage import io
import cv2

class NumberRecog:
	def __init__(self,path_to_files='../masks'):
		self.no_imgs = [None]*10
		self.last_score = 0
		for i in range(10):
			filename = path_to_files+'/{}.png'.format(i)
			self.no_imgs[i] = io.imread(filename)[:,:,:3]

	def clean_img(self,img_to_clean,thresh=25):
		r, g, b = img_to_clean[:,:,0], img_to_clean[:,:,1], img_to_clean[:,:,2]
		mask = (abs(r - g) > thresh) & (abs(g-b) > thresh)
		img_to_clean[mask] = [0,255,0]
		return img_to_clean

	def test_img(self,img_to_test,thresh=50):
		res = []
		img_to_test = self.clean_img(img_to_test)
		for i in reversed(range(7)):
		    arr = [np.mean(cv2.absdiff(img_to_test[:,12*i:12*(i+1),:],self.no_imgs[n])) \
		         for n in range(len(self.no_imgs))]
		    if min(arr) > thresh: break
		    res += [np.argmin(arr)]
		    #print(min(arr))
		res.reverse()
		torstr = ''.join(map(str, res))
		tor = int(torstr)
		if tor  < self.last_score:
			tor = self.last_score
		else:
			self.last_score = tor
		return tor

	def reset(self):
		self.last_score = 0
    
	def test(self,img_to_test):
		try:
			return self.test_img(img_to_test)
		except:
			return self.last_score

if __name__ == '__main__':
	testng = NumberRecog()

# %%
NR = NumberRecog('../masks')
cap = cv2.VideoCapture(1)
cap.set(3,256)
cap.set(4,384)
while(True):
    # Capture frame-by-frame
    ret, frame = cap.read()

    # Our operations on the frame come here
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    res = str(NR.test(frame[52:68,-94:-10,:]))
    cv2.putText(frame,res,(0,220), cv2.FONT_HERSHEY_DUPLEX, 1,(0,255,0),2)
    # Display the resulting frame
    cv2.imshow('frame',frame)
   
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    elif cv2.waitKey(1) & 0xFF == ord('o'):
        print(res)

# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()

# %%
NR = NumberRecog('../masks')

# %%
np.where(np.array(test_all) > 50000)
# Out:
# (array([ 196,  197,  198, ..., 3228, 3229, 3230], dtype=int64),)

# %%
i = 1
filename = '../extracted/out-{}.png'.format(i)
testimg = io.imread(filename)
plt.imshow(NR.clean_img(testimg[52:68,-94:-10,:],25))
plt.show()
NR.test_img(testimg[52:68,-94:-10,:],50)
# lol so it looks like when the bg is gray (aka you messed up) my technique doesn't work
# but this doesn't matter since messing up will just have the last score anyways
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-198-694b428d6ced> in <module>()
#       4 plt.imshow(NR.clean_img(testimg[52:68,-94:-10,:],25))
#       5 plt.show()
# ----> 6 NR.test_img(testimg[52:68,-94:-10,:],50)
#
# <ipython-input-177-c5e1e9dfcd4f> in test_img(self, img_to_test, thresh)
#      29                 res.reverse()
#      30                 torstr = ''.join(map(str, res))
# ---> 31                 tor = int(torstr)
#      32                 if tor  < self.last_score:
#      33                         tor = self.last_score
#
# ValueError: invalid literal for int() with base 10: ''

# %%
i = 3228
filename = '../extracted/out-{}.png'.format(i)
testimg = io.imread(filename)
plt.imshow(NR.clean_img(testimg[52:68,-94:-10,:],25))
plt.show()
NR.test_img(testimg[52:68,-94:-10,:],50)
# Out:
# 48420

# %%
NR.last_score
# Out:
# 0

# %%
test_all = []
for i in range(1,3252):
    filename = '../extracted/out-{}.png'.format(i)
    testimg = io.imread(filename)
    test_all += [NR.test(testimg[52:68,-94:-10,:])]

# %%
test_all
# Out:
# [7550, 7550, 7550, 7550, 7550, 7550, 7550, 7550, 7550]

# %%
plt.plot(test_all)
# not working so great huh

# %%
plt.plot(test_all)
plt.axis([0,3252,-1,50000])
# not bad..
# Out:
# [0, 3252, -1, 50000]

# %%
plt.plot(test_all)
plt.axis([0,3252,-1,50000])
# (almost) no more -1s lol
# Out:
# [0, 3252, -1, 50000]

# %%
plt.plot(test_all)
plt.axis([0,3252,-1,50000])
# Out:
# [0, 3252, -1, 50000]

# %%
plt.plot(test_all)
plt.axis([0,3252,-1,50000])
#perfect ^-^
# Out:
# [0, 3252, -1, 50000]

# %%
NR.test_img(frame[52:68,-94:-10,:])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-182-315d7e46d2e8> in <module>()
# ----> 1 NR.test_img(frame[52:68,-94:-10,:])
#
# <ipython-input-177-c5e1e9dfcd4f> in test_img(self, img_to_test, thresh)
#      29                 res.reverse()
#      30                 torstr = ''.join(map(str, res))
# ---> 31                 tor = int(torstr)
#      32                 if tor  < self.last_score:
#      33                         tor = self.last_score
#
# ValueError: invalid literal for int() with base 10: ''

# %%
np.savetxt('test_res.csv',np.array(test_all),delimiter=',')
